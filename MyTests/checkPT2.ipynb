# %%
import numpy as np
import matplotlib.pylab as plt

#A = np.loadtxt('../full_hamiltonians/h6_1p00_chain.txt')
#A = np.loadtxt('ch4_sto6g_fullCI.txt')
#print(A.shape)
#print(A[0][0])
E = -4.011042954447808739e+01
#
firstC = np.loadtxt('firstC.txt')
diag = np.loadtxt('diag.txt')

#A = np.loadtxt('h2_6-31g_fullCI.txt')
#
#E = A[0][0]
#firstC = np.zeros(len(A[:,0]) - 1)
#diag = np.zeros(len(A[:,0]) - 1)

#for i in range(len(A[:,0]) - 1):
#    firstC[i] = A[i+1][0] 
#    diag[i] = A[i+1][i+1]


ENPT2 = 0.
#diag_copy = diag
#np.sort(diag_copy,kind='stable')
#for i in range(len(diag_copy)-1):
#    if abs(diag_copy[i] - diag_copy[i+1]) < 1e-15:
#        print(i,diag_copy[i],diag_copy[i+1])
#for i in range(len(diag)):
#    print(f'The {i:6d}-th diagonal element is {diag[i]:.12e}')
count = 0
print()
denom = []
sigma = []
dE = []
extDiag = []
for i in range(len(diag)):
#    if (abs(firstC[i]) > 1e-4):
#        extDiag.append(diag[i])
#        denom.append(E - diag[i])
#        sigma.append(firstC[i])
#        dE.append(sigma[-1]*sigma[-1]/denom[-1])
#        #print(f'The {i:6d}-th de is {de:.12e}')
#        #print(f'The {i:6d}-th sigma is {firstC[i]:.12e}')
#        #print(f'The {i:6d}-th denom is {denom:.12e}')
#        #print()
#        count = count + 1
#        ENPT2 = ENPT2 + dE[-1]
    ENPT2 = ENPT2 + firstC[i]*firstC[i]/(E - diag[i])
print(ENPT2)
print(ENPT2 + E)
#dE = np.array(dE)
#sigma = np.array(sigma)
#denom = np.array(denom)
#extDiag = np.array(extDiag)
#sorted_index = np.argsort(-np.abs(dE), kind = 'stable')
#dE = dE[sorted_index]
#sigma = sigma[sorted_index]
#denom = denom[sorted_index]
#extDiag = extDiag[sorted_index]
#
#print("sigma")
#
#for i in range(len(sigma)):
#    if i%5:
#        print(sigma[i],end=', ')
#    else:
#        print()
#        print(sigma[i],end=', ')
#
#print("denom")
#
#for i in range(len(denom)):
#    if i%5:
#        print(denom[i],end=', ')
#    else:
#        print()
#        print(denom[i],end=', ')
#
#print("end denom")
#ENPT2 = 0
#for i in range(len(denom)):
#    ENPT2 = ENPT2 + sigma[i]*sigma[i]/denom[i]
#    print(i, sigma[i], denom[i],dE[i],extDiag[i])
#
#print(ENPT2)
#print(count)
# Out:
# -0.08204197400910891
# -40.192471518487196
